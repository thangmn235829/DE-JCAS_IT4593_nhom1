# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.dirname(os.path.abspath(__file__)))

from generateSteeringVector import generateSteeringVector
from generateDesPattern import generateDesPattern
from twoStepILS import twoStepILS
from displacePattern import displacePattern
from generateQuantizedArrResponse import generateQuantizedArrResponse


def main():
    plt.close("all")

    # Variable initialization
    theta = np.deg2rad(np.arange(-90, 90, 0.1))
    lambda_ = 1
    M = 12
    A = generateSteeringVector(theta, M, lambda_)
    desDirs_c = np.array([0.0])
    W_ref = np.zeros((M, len(desDirs_c)), dtype=complex)

    Q = 160
    phi = 1
    eqDir = np.arange(-1, 1, phi / Q)
    Aq = generateQuantizedArrResponse(M, eqDir)

    # Generate desired pattern
    PdM, P_refGen, W0 = generateDesPattern(eqDir, np.sin(desDirs_c[0]), Aq)
    P_init = np.ones_like(eqDir)
    PM = P_init.copy()

    # Indices - sửa để tránh index out of bounds
    alpha1 = np.arange(0, len(eqDir), 4)
    alpha2 = np.where(PdM > 0)[0]
    alpha = np.sort(np.unique(np.concatenate([alpha1, alpha2])))

    # Đảm bảo alpha không vượt quá kích thước
    alpha = alpha[alpha < len(PM)]
    alpha = alpha[alpha < len(PdM)]

    print(f"PM shape: {PM.shape}, PdM shape: {PdM.shape}, alpha max: {alpha.max()}")

    # Optimize
    W_opt = twoStepILS(50, alpha, Aq, W0.reshape(-1, 1), PM, PdM)
    W_ref[:, 0] = W_opt.flatten()

    # Plot optimized beams
    plt.figure(figsize=(10, 6))
    plt.plot(eqDir, np.zeros_like(eqDir), label="Initial")
    plt.plot(
        eqDir,
        10 * np.log10(PdM / np.max(PdM) + 1e-10),
        "m-*",
        label="Desired",
        markersize=3,
    )
    plt.plot(
        eqDir,
        10 * np.log10(P_refGen / np.max(P_refGen) + 1e-10),
        "--k",
        label="Conventional 12-element ULA",
    )

    pattern_opt = np.abs(W_ref.conj().T @ Aq)
    pattern_opt_norm = pattern_opt / np.max(pattern_opt)
    plt.plot(
        eqDir, 10 * np.log10(pattern_opt_norm.flatten() + 1e-10), "r", label="Optimized"
    )

    plt.legend(loc="upper center", bbox_to_anchor=(0.5, 1.15), ncol=4)
    plt.xlabel("Equivalent directions")
    plt.ylabel("|A|, dB")
    plt.xlim([-1, 1])
    plt.ylim([-35, 1])
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Displace the reference beam
    spacing = 0.2
    deltas = np.arange(-0.8, 0.8 + spacing / 2, spacing)
    W_dd = np.zeros((M, len(deltas)), dtype=complex)

    for i in range(len(deltas)):
        W_dd[:, i] = displacePattern(W_ref, deltas[i], M).flatten()

    # Plot displaced beams
    plt.figure(figsize=(10, 6))
    for i in range(len(deltas)):
        pattern = np.abs(W_dd[:, i].conj().T @ Aq)
        plt.plot(eqDir, 10 * np.log10(pattern / np.max(pattern) + 1e-10))

    plt.xlim([-1, 1])
    plt.ylim([-35, 0])
    plt.xlabel("Equivalent directions")
    plt.ylabel("|A|, dB")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Combination of beams
    ro = 0.5
    W_dd = W_dd / np.linalg.norm(W_dd, axis=0, keepdims=True)
    comBeamIdx = len(deltas) // 2

    W_t = np.zeros((M, len(deltas) - 1), dtype=complex)
    j = 0

    for i in range(W_dd.shape[1]):
        if i != comBeamIdx:
            W_t[:, j] = np.sqrt(ro) * W_dd[:, comBeamIdx] + np.sqrt(1 - ro) * W_dd[:, i]
            j += 1

    # Plot combined beams
    plt.figure(figsize=(10, 6))
    for i in range(W_t.shape[1]):
        pattern = np.abs(W_t[:, i].conj().T @ A)
        plt.plot(theta, 10 * np.log10(pattern / np.max(pattern) + 1e-10))

    plt.xlabel("θ (rad)")
    plt.ylabel("|A(θ)| (dB)")
    plt.grid(True)
    plt.xlim([-np.pi / 2, np.pi / 2])
    plt.ylim([-15, 0])
    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# PM shape: (320,), PdM shape: (320,), alpha max: 316
# Iteration 1, Total difference is 89.483987
# Iteration 2, Total difference is 29.034784
# Iteration 3, Total difference is 29.261154
# Iteration 4, Total difference is 29.372244
# Iteration 5, Total difference is 29.431256
# Iteration 6, Total difference is 29.464171
# Iteration 7, Total difference is 29.483230
# Iteration 8, Total difference is 29.494709
# Iteration 9, Total difference is 29.501913
# Iteration 10, Total difference is 29.506656
# Iteration 11, Total difference is 29.509964
# Iteration 12, Total difference is 29.512415
# Iteration 13, Total difference is 29.514336
# Iteration 14, Total difference is 29.515917
# Iteration 15, Total difference is 29.517268
# Iteration 16, Total difference is 29.518453
# Iteration 17, Total difference is 29.519512
# Iteration 18, Total difference is 29.520470
# Iteration 19, Total difference is 29.521344
# Iteration 20, Total difference is 29.522144
# Iteration 21, Total difference is 29.522879
# Iteration 22, Total difference is 29.523555
# Iteration 23, Total difference is 29.524179
# Iteration 24, Total difference is 29.524754
# Iteration 25, Total difference is 29.525285
# Iteration 26, Total difference is 29.525775
# Iteration 27, Total difference is 29.526228
# Iteration 28, Total difference is 29.526646
# Iteration 29, Total difference is 29.527032
# Iteration 30, Total difference is 29.527389
# Iteration 31, Total difference is 29.527718
# Iteration 32, Total difference is 29.528022
# Iteration 33, Total difference is 29.528303
# Iteration 34, Total difference is 29.528563
# Iteration 35, Total difference is 29.528802
# Iteration 36, Total difference is 29.529024
# Iteration 37, Total difference is 29.529229
# Iteration 38, Total difference is 29.529418
# Iteration 39, Total difference is 29.529592
# Iteration 40, Total difference is 29.529754
# Iteration 41, Total difference is 29.529903
# Iteration 42, Total difference is 29.530041
# Iteration 43, Total difference is 29.530168
# Iteration 44, Total difference is 29.530286
# Iteration 45, Total difference is 29.530395
# Iteration 46, Total difference is 29.530495
# Iteration 47, Total difference is 29.530588
# Iteration 48, Total difference is 29.530674
# Iteration 49, Total difference is 29.530753
# Iteration 50, Total difference is 29.530827
